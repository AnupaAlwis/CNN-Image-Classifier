# %% [markdown]
# ## Import the Required Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers,  models, datasets
from tensorflow.keras.layers import Conv2D, LeakyReLU

# %% [markdown]
# ## Loading the Dataset

# %%
(train_data, train_labels), (test_data, test_labels) = datasets.mnist.load_data() #Used the Mnist Data Set

# %% [markdown]
# ## Concatanating the Dataset

# %%
concatenated_data = np.concatenate((train_data, test_data), axis=0)
concatenated_labels = np.concatenate((train_labels, test_labels), axis=0)

#Normalization
concatenated_data = concatenated_data / 255.0

# %% [markdown]
# ## Split the dataset

# %%
# Split the combined dataset into train, validation, and test sets
data_train, data_temp, labels_train, labels_temp = train_test_split(concatenated_data, concatenated_labels, test_size=0.4, random_state=42) #Split the training set
data_val, data_test, labels_val, labels_test = train_test_split(data_temp, labels_temp, test_size=0.5, random_state=42) #Split the validations and test set

# %% [markdown]
# ## Reshape Data

# %%
#Convert each 2D image into 3D one
data_train = data_train.reshape(-1, 28, 28, 1)
data_val = data_val.reshape(-1, 28, 28, 1)
data_test = data_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# ## Building the model

# %%
model = tf.keras.models.Sequential()

# First convolutional layer with LeakyReLU activation, followed by Batch Normalization and MaxPooling
model.add(Conv2D(32, kernel_size=3, activation=LeakyReLU(alpha=0.001), input_shape=(28, 28, 1)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

# Second convolutional layer with LeakyReLU activation, followed by Batch Normalization and MaxPooling
model.add(Conv2D(32, kernel_size=3, activation=LeakyReLU(alpha=0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

# Third convolutional layer with LeakyReLU activation, followed by Batch Normalization and MaxPooling
model.add(Conv2D(32, kernel_size=3, activation=LeakyReLU(alpha=0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

#Flattern Layer
model.add(tf.keras.layers.Flatten())

# Dense (fully connected) layer with 128 units and LeakyReLU activation
model.add(tf.keras.layers.Dense(128, activation=LeakyReLU(alpha=0.001)))

# Dropout layer to reduce overfitting during training
model.add(tf.keras.layers.Dropout(0.4))

# Output layer with 10 units (one for each class) and softmax activation for classification
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 11, 11, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 1, 1, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,714 (96.54 KB)
#  Trainable params: 24,522 (95.79 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## Training The Model

# %%
history = model.fit(data_train, labels_train, epochs=20, validation_data=(data_val, labels_val))
# Out:
# Epoch 1/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.4991 - loss: 1.5173 - val_accuracy: 0.9291 - val_loss: 0.2551
# Epoch 2/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9155 - loss: 0.2932 - val_accuracy: 0.9559 - val_loss: 0.1470
# Epoch 3/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9450 - loss: 0.1824 - val_accuracy: 0.9647 - val_loss: 0.1129
# Epoch 4/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9597 - loss: 0.1379 - val_accuracy: 0.9684 - val_loss: 0.0993
# Epoch 5/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9668 - loss: 0.1111 - val_accuracy: 0.9730 - val_loss: 0.0868
# Epoch 6/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9716 - loss: 0.0930 - val_accuracy: 0.9762 - val_loss: 0.0797
# Epoch 7/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9755 - loss: 0.0830 - val_accuracy: 0.9769 - val_loss: 0.0749
# Epoch 8/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9801 - loss: 0.0674 - val_accuracy: 0.9786 - val_loss: 0.0733
# Epoch 9/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9807 - loss: 0.0672 - val_accuracy: 0.9776 - val_loss: 0.0719
# Epoch 10/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9833 - loss: 0.0581 - val_accuracy: 0.9784 - val_loss: 0.0693
# Epoch 11/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9848 - loss: 0.0500 - val_accuracy: 0.9804 - val_loss: 0.0669
# Epoch 12/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9859 - loss: 0.0474 - val_accuracy: 0.9806 - val_loss: 0.0680
# Epoch 13/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9869 - loss: 0.0416 - val_accuracy: 0.9801 - val_loss: 0.0655
# Epoch 14/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9874 - loss: 0.0417 - val_accuracy: 0.9823 - val_loss: 0.0626
# Epoch 15/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9902 - loss: 0.0351 - val_accuracy: 0.9818 - val_loss: 0.0607
# Epoch 16/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9892 - loss: 0.0341 - val_accuracy: 0.9826 - val_loss: 0.0625
# Epoch 17/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9920 - loss: 0.0290 - val_accuracy: 0.9814 - val_loss: 0.0653
# Epoch 18/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9910 - loss: 0.0300 - val_accuracy: 0.9826 - val_loss: 0.0654
# Epoch 19/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9927 - loss: 0.0241 - val_accuracy: 0.9822 - val_loss: 0.0635
# Epoch 20/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.9925 - loss: 0.0232 - val_accuracy: 0.9821 - val_loss: 0.0667

# %% [markdown]
# ## Plotting the Training & Validation Loss

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o') #Training Loss
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o') # Validation Loss
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluating Model Performance with Classification Report and Confusion Matrix Visualization

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np

# Get predictions from the model
pred = model.predict(data_test)

pred_classes = np.argmax(pred, axis=1)

print(classification_report(labels_test, pred_classes, digits=2))
conf_matrix = confusion_matrix(labels_test, pred_classes)

class_labels = [str(i) for i in range(10)]
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1419
#            1       0.99      0.99      0.99      1607
#            2       0.97      0.98      0.97      1403
#            3       0.99      0.97      0.98      1437
#            4       0.98      0.99      0.98      1326
#            5       0.98      0.98      0.98      1249
#            6       0.99      0.99      0.99      1351
#            7       0.97      0.98      0.98      1488
#            8       0.98      0.97      0.98      1319
#            9       0.98      0.97      0.97      1401
#
#     accuracy                           0.98     14000
#    macro avg       0.98      0.98      0.98     14000
# weighted avg       0.98      0.98      0.98     14000

# %% [markdown]
# ## Training & Validation Losses for different learning rates

# %% [markdown]
# 1. When Learning rate = 0.001

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(data_train, labels_train, epochs=20, validation_data=(data_val, labels_val))

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o') #Training Loss
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o') # Validation Loss
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9722 - loss: 0.0893 - val_accuracy: 0.9789 - val_loss: 0.0738
# Epoch 2/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9822 - loss: 0.0571 - val_accuracy: 0.9802 - val_loss: 0.0681
# Epoch 3/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9848 - loss: 0.0505 - val_accuracy: 0.9821 - val_loss: 0.0630
# Epoch 4/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9868 - loss: 0.0416 - val_accuracy: 0.9823 - val_loss: 0.0606
# Epoch 5/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9877 - loss: 0.0400 - val_accuracy: 0.9814 - val_loss: 0.0670
# Epoch 6/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9886 - loss: 0.0350 - val_accuracy: 0.9837 - val_loss: 0.0605
# Epoch 7/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9893 - loss: 0.0345 - val_accuracy: 0.9828 - val_loss: 0.0677
# Epoch 8/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9916 - loss: 0.0277 - val_accuracy: 0.9841 - val_loss: 0.0670
# Epoch 9/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9915 - loss: 0.0261 - val_accuracy: 0.9820 - val_loss: 0.0752
# Epoch 10/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9911 - loss: 0.0268 - val_accuracy: 0.9854 - val_loss: 0.0588
# Epoch 11/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9924 - loss: 0.0211 - val_accuracy: 0.9851 - val_loss: 0.0594
# Epoch 12/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9937 - loss: 0.0191 - val_accuracy: 0.9834 - val_loss: 0.0675
# Epoch 13/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9945 - loss: 0.0164 - val_accuracy: 0.9845 - val_loss: 0.0688
# Epoch 14/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9929 - loss: 0.0212 - val_accuracy: 0.9820 - val_loss: 0.0752
# Epoch 15/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9954 - loss: 0.0151 - val_accuracy: 0.9856 - val_loss: 0.0711
# Epoch 16/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9948 - loss: 0.0152 - val_accuracy: 0.9845 - val_loss: 0.0692
# Epoch 17/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9953 - loss: 0.0141 - val_accuracy: 0.9866 - val_loss: 0.0617
# Epoch 18/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9960 - loss: 0.0125 - val_accuracy: 0.9850 - val_loss: 0.0665
# Epoch 19/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9830 - val_loss: 0.0774
# Epoch 20/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9958 - loss: 0.0123 - val_accuracy: 0.9851 - val_loss: 0.0749

# %% [markdown]
# 2. When Learning rate = 0.01

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(data_train, labels_train, epochs=20, validation_data=(data_val, labels_val))

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o') #Training Loss
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o') # Validation Loss
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9575 - loss: 0.1602 - val_accuracy: 0.9760 - val_loss: 0.0918
# Epoch 2/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9740 - loss: 0.0981 - val_accuracy: 0.9671 - val_loss: 0.1070
# Epoch 3/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9763 - loss: 0.0841 - val_accuracy: 0.9730 - val_loss: 0.1203
# Epoch 4/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9777 - loss: 0.0813 - val_accuracy: 0.9783 - val_loss: 0.0813
# Epoch 5/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9803 - loss: 0.0741 - val_accuracy: 0.9658 - val_loss: 0.1237
# Epoch 6/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9817 - loss: 0.0713 - val_accuracy: 0.9816 - val_loss: 0.0847
# Epoch 7/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9826 - loss: 0.0667 - val_accuracy: 0.9788 - val_loss: 0.0886
# Epoch 8/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9813 - loss: 0.0694 - val_accuracy: 0.9819 - val_loss: 0.0715
# Epoch 9/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9832 - loss: 0.0664 - val_accuracy: 0.9811 - val_loss: 0.0868
# Epoch 10/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9867 - loss: 0.0513 - val_accuracy: 0.9829 - val_loss: 0.0780
# Epoch 11/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9844 - loss: 0.0602 - val_accuracy: 0.9824 - val_loss: 0.0783
# Epoch 12/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.9846 - loss: 0.0562 - val_accuracy: 0.9798 - val_loss: 0.0943
# Epoch 13/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9843 - loss: 0.0642 - val_accuracy: 0.9796 - val_loss: 0.1193
# Epoch 14/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9842 - loss: 0.0642 - val_accuracy: 0.9794 - val_loss: 0.1158
# Epoch 15/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9875 - loss: 0.0525 - val_accuracy: 0.9793 - val_loss: 0.1168
# Epoch 16/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9861 - loss: 0.0571 - val_accuracy: 0.9822 - val_loss: 0.1156
# Epoch 17/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9861 - loss: 0.0533 - val_accuracy: 0.9811 - val_loss: 0.1169
# Epoch 18/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9863 - loss: 0.0583 - val_accuracy: 0.9846 - val_loss: 0.0779
# Epoch 19/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.9871 - loss: 0.0541 - val_accuracy: 0.9829 - val_loss: 0.0935
# Epoch 20/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.9877 - loss: 0.0495 - val_accuracy: 0.9809 - val_loss: 0.1156

# %% [markdown]
# 3. When Learning rate = 0.1

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(data_train, labels_train, epochs=20, validation_data=(data_val, labels_val))

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o') #Training Loss
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o') # Validation Loss
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - accuracy: 0.6771 - loss: 1.4241 - val_accuracy: 0.8659 - val_loss: 0.6129
# Epoch 2/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.6844 - loss: 1.0900 - val_accuracy: 0.8016 - val_loss: 3.3090
# Epoch 3/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.7350 - loss: 1.0106 - val_accuracy: 0.8728 - val_loss: 0.4187
# Epoch 4/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.6408 - loss: 1.5410 - val_accuracy: 0.7575 - val_loss: 0.6767
# Epoch 5/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7156 - loss: 1.0639 - val_accuracy: 0.8341 - val_loss: 0.8824
# Epoch 6/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.7053 - loss: 1.1766 - val_accuracy: 0.9047 - val_loss: 0.3499
# Epoch 7/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.6838 - loss: 1.3994 - val_accuracy: 0.9232 - val_loss: 0.2575
# Epoch 8/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7722 - loss: 0.9366 - val_accuracy: 0.8550 - val_loss: 7.9073
# Epoch 9/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7066 - loss: 1.4159 - val_accuracy: 0.9246 - val_loss: 0.3354
# Epoch 10/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.7867 - loss: 0.9902 - val_accuracy: 0.8759 - val_loss: 0.5452
# Epoch 11/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7781 - loss: 1.0476 - val_accuracy: 0.8759 - val_loss: 0.5024
# Epoch 12/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7724 - loss: 1.1772 - val_accuracy: 0.8048 - val_loss: 12.9724
# Epoch 13/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7088 - loss: 1.6433 - val_accuracy: 0.9298 - val_loss: 0.2491
# Epoch 14/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.8010 - loss: 0.9729 - val_accuracy: 0.9086 - val_loss: 0.5016
# Epoch 15/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7515 - loss: 1.2585 - val_accuracy: 0.9064 - val_loss: 0.3355
# Epoch 16/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7809 - loss: 1.1838 - val_accuracy: 0.8901 - val_loss: 0.3955
# Epoch 17/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.7664 - loss: 1.2919 - val_accuracy: 0.9215 - val_loss: 0.3349
# Epoch 18/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7534 - loss: 1.7498 - val_accuracy: 0.9251 - val_loss: 1.7588
# Epoch 19/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.8179 - loss: 1.0987 - val_accuracy: 0.9350 - val_loss: 0.3094
# Epoch 20/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.8084 - loss: 1.1680 - val_accuracy: 0.9265 - val_loss: 0.4159
