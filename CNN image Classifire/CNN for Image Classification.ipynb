# %%
# import necessary libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time

from tensorflow.keras import datasets, callbacks
from tensorflow import keras
import opendatasets as od
import pandas as pd
import os
import cv2
import shutil
import splitfolders
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
# Load the MNIST dataset
(train_data, train_labels), (test_data, test_labels) = datasets.mnist.load_data()

# Concatenate the training and test sets
all_data = np.concatenate((train_data, test_data), axis=0)
all_labels = np.concatenate((train_labels, test_labels), axis=0)

# Normalize pixel values between 0 and 1
all_data = all_data / 255.0

# Split the combined dataset into train, validation, and test sets
data_train, data_temp, labels_train, labels_temp = train_test_split(all_data, all_labels, test_size=0.4, random_state=42)
data_val, data_test, labels_val, labels_test = train_test_split(data_temp, labels_temp, test_size=0.5, random_state=42)

# Reshape data for the neural network input
data_train = data_train.reshape(-1, 28, 28, 1)
data_val = data_val.reshape(-1, 28, 28, 1)
data_test = data_test.reshape(-1, 28, 28, 1)

# Debug: Check shapes of the data
print(f"Training data shape: {all_data.shape}")
print(f"Training data shape: {data_train.shape}")
print(f"Validation data shape: {data_val.shape}")
print(f"Test data shape: {data_test.shape}")
# Out:
# Training data shape: (70000, 28, 28)
# Training data shape: (42000, 28, 28, 1)
# Validation data shape: (14000, 28, 28, 1)
# Test data shape: (14000, 28, 28, 1)

# %%
#Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal",input_shape=(128,128,1)),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2)
])
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Model Building
model = tf.keras.models.Sequential()

model.add(data_augmentation)

model.add(tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu',input_shape=(28, 28, 1)))
#model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'))
#model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'))
#model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(128, activation='relu'))

model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Dense(5, activation='softmax'))

model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,605,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,662,149 (6.34 MB)
#  Trainable params: 1,662,149 (6.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 130,890 (511.29 KB)
#  Trainable params: 130,890 (511.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Learning rate scheduler
lr_scheduler = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1
)

# Early stopping to avoid overfitting
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=7,
    verbose=1,
    restore_best_weights=True
)

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                #from_logits=True,
                ignore_class=None,
                reduction='sum_over_batch_size'
              ),
              metrics=['accuracy'])

# Train the model
history = model.fit(data_train, labels_train, epochs=20, 
                    batch_size=128, validation_data=(data_val, labels_val),verbose=2,
                    callbacks=[lr_scheduler, early_stopping]
                    )
# Out:
# Epoch 1/20
# 329/329 - 9s - 26ms/step - accuracy: 0.8830 - loss: 0.3718 - val_accuracy: 0.9729 - val_loss: 0.0886 - learning_rate: 0.0010
# Epoch 2/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9717 - loss: 0.0971 - val_accuracy: 0.9826 - val_loss: 0.0592 - learning_rate: 0.0010
# Epoch 3/20
# 329/329 - 7s - 21ms/step - accuracy: 0.9798 - loss: 0.0684 - val_accuracy: 0.9858 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 4/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9839 - loss: 0.0559 - val_accuracy: 0.9889 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 5/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9858 - loss: 0.0458 - val_accuracy: 0.9886 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 6/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9875 - loss: 0.0403 - val_accuracy: 0.9864 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 7/20
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 329/329 - 7s - 20ms/step - accuracy: 0.9892 - loss: 0.0359 - val_accuracy: 0.9894 - val_loss: 0.0364 - learning_rate: 0.0010
# Epoch 8/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9932 - loss: 0.0221 - val_accuracy: 0.9924 - val_loss: 0.0274 - learning_rate: 5.0000e-04
# Epoch 9/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9937 - loss: 0.0196 - val_accuracy: 0.9919 - val_loss: 0.0289 - learning_rate: 5.0000e-04
# Epoch 10/20
# 329/329 - 7s - 23ms/step - accuracy: 0.9945 - loss: 0.0182 - val_accuracy: 0.9908 - val_loss: 0.0325 - learning_rate: 5.0000e-04
# Epoch 11/20
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 329/329 - 7s - 21ms/step - accuracy: 0.9952 - loss: 0.0158 - val_accuracy: 0.9922 - val_loss: 0.0282 - learning_rate: 5.0000e-04
# Epoch 12/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9967 - loss: 0.0114 - val_accuracy: 0.9925 - val_loss: 0.0273 - learning_rate: 2.5000e-04
# Epoch 13/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 0.9929 - val_loss: 0.0285 - learning_rate: 2.5000e-04
# Epoch 14/20
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 329/329 - 7s - 20ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9921 - val_loss: 0.0277 - learning_rate: 2.5000e-04
# Epoch 15/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9978 - loss: 0.0079 - val_accuracy: 0.9929 - val_loss: 0.0264 - learning_rate: 1.2500e-04
# Epoch 16/20
# 329/329 - 7s - 20ms/step - accuracy: 0.9978 - loss: 0.0074 - val_accuracy: 0.9924 - val_loss: 0.0277 - learning_rate: 1.2500e-04
# Epoch 17/20
# 329/329 - 7s - 21ms/step - accuracy: 0.9980 - loss: 0.0065 - val_accuracy: 0.9926 - val_loss: 0.0301 - learning_rate: 1.2500e-04
# Epoch 18/20
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 329/329 - 7s - 21ms/step - accuracy: 0.9979 - loss: 0.0066 - val_accuracy: 0.9928 - val_loss: 0.0291 - learning_rate: 1.2500e-04
# Epoch 19/20
# 329/329 - 7s - 22ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9928 - val_loss: 0.0292 - learning_rate: 6.2500e-05
# Epoch 20/20
# 329/329 - 7s - 21ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9928 - val_loss: 0.0293 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 15.

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', linestyle='--', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Get predictions from the model
pred = model.predict(data_test)

pred_classes = np.argmax(pred, axis=1)

print(classification_report(labels_test, pred_classes, digits=2))
conf_matrix = confusion_matrix(labels_test, pred_classes)

# Confusion matrix heatmap
class_labels = [str(i) for i in range(10)]
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1419
#            1       1.00      1.00      1.00      1607
#            2       0.99      0.99      0.99      1403
#            3       0.99      0.99      0.99      1437
#            4       0.99      0.99      0.99      1326
#            5       0.98      0.99      0.99      1249
#            6       1.00      0.99      0.99      1351
#            7       0.99      0.99      0.99      1488
#            8       0.98      0.99      0.99      1319
#            9       0.99      0.99      0.99      1401
#
#     accuracy                           0.99     14000
#    macro avg       0.99      0.99      0.99     14000
# weighted avg       0.99      0.99      0.99     14000

# %%
# Display a single test image with prediction
index = 50 
single_image = data_test[index]

# Reshape the image to fit the input shape of the CNN model (batch size of 1, height, width, channels)
single_image_reshaped = single_image.reshape(1, 28, 28, 1)

# Make prediction
prediction = model.predict(single_image_reshaped)
predicted_class = np.argmax(prediction, axis=1)
true_class = labels_test[index]

# Display the image along with the predicted and true class
plt.imshow(single_image.reshape(28, 28), cmap='gray')
plt.title(f"True Label: {true_class}, Predicted Label: {predicted_class[0]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
# Load a custom image for prediction
image = cv2.imread("C:/Users/Kavishka Lakshan/Downloads/download.png")
plt.imshow(image)
plt.show()

# %%
# Preprocess the custom image
def preprocess_image(image):
    gray = cv2.bitwise_not(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)) 
    resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA) 
    return resized / 255.0 

preprocessed_image = preprocess_image(image)
plt.imshow(preprocessed_image, cmap='gray')
plt.axis("off")
plt.title("Preprocessed Image")
plt.show()

input_image = preprocessed_image.reshape(1, 28, 28, 1)
predicted_class = np.argmax(model.predict(input_image), axis=1)[0]
print(f"Predicted class: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted class: 9
